# %% [markdown]
# # How to use git with Jupyter

# %% [markdown]
# A simple demo to show you how to use it

# %%
from matplotlib import pyplot as plt

# %%
plt.figure()
plt.plot([1, 2, 3], [1, 4, 2], color='red')
plt.show()
